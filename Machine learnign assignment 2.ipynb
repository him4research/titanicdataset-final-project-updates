# %%
import numpy as np # for using the liner algebra 
import pandas as pd # for processing our data and isv file I/O
import os 
print(os.listdir("G:\\Data Science"))
#from collections import counter 
# %pylab inline
# Out:
# ['gender_submission (1).csv', 'notebook.ipynb', 'test.csv', 'train.csv']
# Populating the interactive namespace from numpy and matplotlib

# %%
train=pd.read_csv("G:/Data Science/train.csv")

# %%
train.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 378          379         0       3                        Betros, Mr. Tannous
# 654          655         0       3               Hegarty, Miss. Hanora "Nora"
# 270          271         0       1                      Cairns, Mr. Alexander
# 842          843         1       1                    Serepeca, Miss. Augusta
# 347          348         1       3  Davison, Mrs. Thomas Henry (Mary E Finck)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 378    male  20.0      0      0    2648   4.0125   NaN        C
# 654  female  18.0      0      0  365226   6.7500   NaN        Q
# 270    male   NaN      0      0  113798  31.0000   NaN        S
# 842  female  30.0      0      0  113798  31.0000   NaN        C
# 347  female   NaN      1      0  386525  16.1000   NaN        S

# %%
 train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.shape
# Out:
# (891, 12)

# %%
train.Sex.value_counts().plot(kind="bar")

# %%
train[train.Sex=="female"].Survived.value_counts().plot(kind='bar')

# %%
train[train.Sex=="male"].Survived.value_counts().plot(kind='bar')

# %%
train[train.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
train[train.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
avgAge = train.Age.mean()

# %%
print(avgAge)
# Out:
# 29.69911764705882

# %%
train.Age.fillna(value=avgAge)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %%
train[train.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
train.loc[train["Sex"]=='male',"Sex"]=0
train.loc[train["Sex"]=='female',"Sex"]=1

# %%
train.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 169          170         0       3
# 619          620         0       2
# 710          711         1       1
# 355          356         0       3
# 202          203         0       3
#
#                                                  Name  Sex   Age  SibSp  \
# 169                                     Ling, Mr. Lee    0  28.0      0
# 619                               Gavey, Mr. Lawrence    0  26.0      0
# 710  Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")    1  24.0      0
# 355                       Vanden Steen, Mr. Leo Peter    0  28.0      0
# 202                        Johanson, Mr. Jakob Alfred    0  34.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 169      0      1601  56.4958   NaN        S
# 619      0     31028  10.5000   NaN        S
# 710      0  PC 17482  49.5042   C90        C
# 355      0    345783   9.5000   NaN        S
# 202      0   3101264   6.4958   NaN        S

# %%
target = train["Survived"].values
fetures = train[["Age","Sex"]].values

# %%
from sklearn.ensemble import RandomForestRegressor
classifier1 = RandomForestRegressor()
classifier_1 =classifier1.fit(fetures,target)
print(classifier_1.score(fetures,target))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-723b04aa7cea> in <module>()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 classifier1 = RandomForestRegressor()
# ----> 3 classifier_1 =classifier1.fit(fetures,target)
#       4 print(classifier_1.score(fetures,target))
#
# G:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ...

# %%
import sklearn
